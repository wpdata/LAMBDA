# %% [markdown]
# # Tutorial1: Installation and Configuration

# %% [markdown]
# ## Step1:Download the Repository

# %%
# !git clone https://github.com/AMA-CMFAI/LAMBDA.git
# %cd LAMBDA
# Out:
# Cloning into 'LAMBDA'...
# remote: Enumerating objects: 198, done.
# remote: Counting objects: 100% (198/198), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 198 (delta 87), reused 114 (delta 40), pack-reused 0 (from 0)
# Receiving objects: 100% (198/198), 159.21 KiB | 1.36 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %% [markdown]
# Make sure your python version is greater than 3.10

# %%
# !python --version
# Out:
# Python 3.11.13

# %% [markdown]
# ## Step2:Install Packages

# %%
# !pip install -r requirements.txt

# %% [markdown]
# Install the trochvision (required by colab)

# %%
# !pip install torchvision

# %% [markdown]
# Create a environment for code interpreter

# %%
# !ipython kernel install --name lambda --user
# Out:
# Installed kernelspec lambda in /root/.local/share/jupyter/kernels/lambda

# %% [markdown]
# ## Configuration
# Open the config.yaml in the left menu and set your api_key.
# > Note, the APIKey you can get by purchase from companies like OpenAI and DeepSeek. Or you can get it by your local model.
# For example, [Ollama](https://ollama.com/blog/openai-compatibility)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Start Data Analysis
# Now, you can start the LAMBDA by on command.

# %%
# !python app.py

# %% [markdown]
# ## You will see the link for open the system.
#
# ![CleanShot 2025-06-30 at 14.56.22@2x.png](data:image/png;base64,...)
